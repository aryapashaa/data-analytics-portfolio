# %% [markdown]
# <a href="https://colab.research.google.com/github/aryapashaa/data-analytics-portofolio/blob/main/Daily_Global_Streams_of_Popular_Songs_in_2017_2018_Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('/spotify.csv')

# %%
df
# Out:
#            Date  Shape of You  ...    HUMBLE.  Unforgettable
# 0    2017-01-06      12287078  ...        NaN            NaN
# 1    2017-01-07      13190270  ...        NaN            NaN
# 2    2017-01-08      13099919  ...        NaN            NaN
# 3    2017-01-09      14506351  ...        NaN            NaN
# 4    2017-01-10      14275628  ...        NaN            NaN
# ..          ...           ...  ...        ...            ...
# 361  2018-01-05       4492978  ...  2685857.0      2869783.0
# 362  2018-01-06       4416476  ...  2559044.0      2743748.0
# 363  2018-01-07       4009104  ...  2350985.0      2441045.0
# 364  2018-01-08       4135505  ...  2523265.0      2622693.0
# 365  2018-01-09       4168506  ...  2727678.0      2627334.0
#
# [366 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Date                         0
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
df2 = df.copy()

# %%
df2.isna().sum()
# Out:
# Date                         0
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.isna().sum()
# Out:
# Date                        0
# Shape of You                0
# Despacito                   0
# Something Just Like This    0
# HUMBLE.                     0
# Unforgettable               0
# dtype: int64

# %%
df2
# Out:
#            Date  Shape of You  ...    HUMBLE.  Unforgettable
# 91   2017-04-07      13042637  ...  8055220.0       317011.0
# 92   2017-04-08      12815920  ...  7280150.0       308838.0
# 93   2017-04-09      11291392  ...  6396104.0       756145.0
# 94   2017-04-10      11819128  ...  7162611.0       954504.0
# 95   2017-04-11      11736951  ...  7468021.0       953037.0
# ..          ...           ...  ...        ...            ...
# 361  2018-01-05       4492978  ...  2685857.0      2869783.0
# 362  2018-01-06       4416476  ...  2559044.0      2743748.0
# 363  2018-01-07       4009104  ...  2350985.0      2441045.0
# 364  2018-01-08       4135505  ...  2523265.0      2622693.0
# 365  2018-01-09       4168506  ...  2727678.0      2627334.0
#
# [275 rows x 6 columns]

# %%
plt.figure(figsize=(15,7))

df2['Date'] = pd.to_datetime(df2['Date'])
df2.sort_values('Date', inplace=True)

plt.plot(df2['Date'],df2['Shape of You'], color = 'red', label = 'Shape of You')
plt.plot(df2['Date'],df2['Despacito'], color = 'orange', label = 'Despacito')
plt.plot(df2['Date'],df2['Something Just Like This'], color = 'yellow', label = 'Something Just Like This')
plt.plot(df2['Date'],df2['HUMBLE.'], color = 'green', label = 'HUMBLE.')
plt.plot(df2['Date'],df2['Unforgettable'], color = 'blue', label = 'Unforgettable')
plt.xlabel('Date')
plt.ylabel('Streams')
plt.title('Daily Global Streams of Popular Songs in 2017-2018')
plt.legend()
plt.show()
